# %% [markdown]
# #Problem 1: Mobile Recharge Validation System
#
#  Problem Statement:
# Create a function to validate a mobile recharge request.
#
# Rules:
# Recharge amount must be ≥ ₹50
#
# Valid plans: 199, 299, 399, 599
#
# User should be allowed to retry if invalid

# %%
def validate_recharge():
    valid_plans = [199, 299, 399, 599]
    is_valid = False   

    while is_valid == False:
        amount = int(input("Enter recharge amount: ₹"))

        if amount < 50:
            print("Recharge amount must be at least ₹50. Please try again.")
        elif amount not in valid_plans:
            print("Invalid plan. Available plans: 199, 299, 399, 599.")
        else:
            print("Recharge successful")
            is_valid = True 

validate_recharge()
# Out:
# Enter recharge amount: ₹ 399
# Recharge successful

# %% [markdown]
# #Problem 2: Inventory Reorder Alert System
#
# Problem Statement:
# Given a dictionary of products and stock quantities:
#
# Print Reorder Alert if stock < 15
#
# Print Stock OK otherwise

# %%
def inventory_alert(x):
    for i in x:
        if x[i] < 15:
            print(i, ": Reorder Alert")
        else:
            print(i, ": Stock OK")

x = {"Rice": 10,"Oil": 25,"Sugar": 12,"Salt": 20}
inventory_alert(x)
# Out:
# Rice : Reorder Alert
# Oil : Stock OK
# Sugar : Reorder Alert
# Salt : Stock OK

# %% [markdown]
# #Problem 3: Student Result Processing System
#
# Problem Statement:
# Create a function that:
#
# Accepts a list of student marks
#
# Calculates average marks
#
# Prints Pass if average ≥ 50 else Fail

# %%
x=[50,40,94,86,75]
def marks_check(x):
    avg=sum(x)/len(x)
    for i in x:
        if i>=avg:
            print((i,"pass"))
        else:
            print((i,"fail"))
marks_check(x)
# Out:
# (50, 'fail')
# (40, 'fail')
# (94, 'pass')
# (86, 'pass')
# (75, 'pass')

# %% [markdown]
# #Problem 4: Cab Fare Estimator with Retry Option
#
# Problem Statement
# Create a cab fare calculator:
#
# Base fare = ₹50
#
# ₹12 per km
#
# Peak hour → 25% extra
#
# Allow retry using while loop

# %%
def cab_fare():
    BASE_FARE = 50
    RATE_PER_KM = 12

    while True:
        km = float(input("Enter distance in km: "))
        peak = input("Is it peak hour? (yes/no): ").lower()

        fare = BASE_FARE + (km * RATE_PER_KM)

        if peak == "yes":
            fare = fare + (fare * 0.25)

        print("Total Fare: ₹", fare)

        again = input("Do you want to calculate again? (yes/no): ").lower()

        if again != "yes":
            print("Thank you for using Cab Fare Estimator")
            break

cab_fare()
# Out:
# Enter distance in km:  13
# Is it peak hour? (yes/no):  no
# Total Fare: ₹ 206.0
# Do you want to calculate again? (yes/no):  no
# Thank you for using Cab Fare Estimator

# %% [markdown]
# #Problem 5: Employee Attendance Eligibility Checker
#
# Problem Statement
# Create a function that:
#
# Accepts attendance list ("P", "A")
#
# Calculates attendance percentage
#
# Returns Eligible if ≥ 75% else Not Eligible

# %%
def eligibility(x):
    countA=0
    countP=0
    for i in x:
        if i=="P":
            countP=countP+1
        else:
            countA=countA+1
    if (countP/len(x))*100==75:
        print("eligible")
    else:
        print("not eligible")

x=["P","P","A","P","A","P","P","P"]
eligibility(x)
# Out:
# eligible

# %% [markdown]
# #Problem 6: Password Strength Checker
#
# Problem Statement
# Create a function to check password strength.
#
# Rules:
#
# Minimum length = 8
#
# Must contain at least one digit
#
# Must contain at least one special character (@#$)

# %%
def pass_checker(x):
    DigitCount=0
    SpecialCount=0
    if len(x)<8:
        return("password length must be greater than 8 characters")
    for i in x:
        if(i.isdigit()==True):
            DigitCount+=1
        if(i in '@#$'):
            SpecialCount+=1
    if(DigitCount<1 or SpecialCount<1):
        return("password either doent have special char or a digit")
    return("Password is good enough")
pass_checker("abcdefg$")
# Out:
# 'password either doent have special char or a digit'
